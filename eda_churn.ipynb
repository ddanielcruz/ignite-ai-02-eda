# %%
import pandas as pd

# %% [markdown]
# ## Create DataFrames from datasets

# %%
# Load customers dataset
df_customers = pd.read_csv('./datasets/churn_customers.csv')
df_customers
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents
# 0     7590-VHVEG  Female              0     Yes         No
# 1     5575-GNVDE    Male              0      No         No
# 2     3668-QPYBK    Male              0      No         No
# 3     7795-CFOCW    Male              0      No         No
# 4     9237-HQITU  Female              0      No         No
# ...          ...     ...            ...     ...        ...
# 7038  6840-RESVB    Male              0     Yes        Yes
# 7039  2234-XADUH  Female              0     Yes        Yes
# 7040  4801-JZAZL  Female              0     Yes        Yes
# 7041  8361-LTMKD    Male              1     Yes         No
# 7042  3186-AJIEK    Male              0      No         No
#
# [7043 rows x 5 columns]

# %%
# Show customers dataset info
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Load services dataset
df_services = pd.read_csv('./datasets/churn_services.csv')
df_services
# Out:
#       customerID PhoneService     MultipleLines InternetService  \
# 0     7590-VHVEG           No  No phone service             DSL
# 1     5575-GNVDE          Yes                No             DSL
# 2     3668-QPYBK          Yes                No             DSL
# 3     7795-CFOCW           No  No phone service             DSL
# 4     9237-HQITU          Yes                No     Fiber optic
# ...          ...          ...               ...             ...
# 7038  6840-RESVB          Yes               Yes             DSL
# 7039  2234-XADUH          Yes               Yes     Fiber optic
# 7040  4801-JZAZL           No  No phone service             DSL
# 7041  8361-LTMKD          Yes               Yes     Fiber optic
# 7042  3186-AJIEK          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# ...

# %%
# Show services dataset info
df_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   PhoneService      7043 non-null   object
#  2   MultipleLines     7043 non-null   object
#  3   InternetService   7043 non-null   object
#  4   OnlineSecurity    7043 non-null   object
#  5   OnlineBackup      7043 non-null   object
#  6   DeviceProtection  7043 non-null   object
#  7   TechSupport       7043 non-null   object
#  8   StreamingTV       7043 non-null   object
#  9   StreamingMovies   7043 non-null   object
# dtypes: object(10)
# memory usage: 550.4+ KB

# %%
# Load contracts dataset
df_contracts = pd.read_csv('./datasets/churn_contracts.csv')
df_contracts
# Out:
#       customerID  Tenure        Contract PaperlessBilling  \
# 0     7590-VHVEG       1  Month-to-month              Yes
# 1     5575-GNVDE      34        One year               No
# 2     3668-QPYBK       2  Month-to-month              Yes
# 3     7795-CFOCW      45        One year               No
# 4     9237-HQITU       2  Month-to-month              Yes
# ...          ...     ...             ...              ...
# 7038  6840-RESVB      24        One year              Yes
# 7039  2234-XADUH      72        One year              Yes
# 7040  4801-JZAZL      11  Month-to-month              Yes
# 7041  8361-LTMKD       4  Month-to-month              Yes
# 7042  3186-AJIEK      66        Two year              Yes
#
#                   PaymentMethod      MonthlyCharges TotalCharges Churn
# 0              Electronic check  29.850000000000001        29.85    No
# 1                  Mailed check  56.950000000000003       1889.5    No
# ...

# %%
# Show contracts dataset info
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   Churn             7043 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 440.3+ KB

# %% [markdown]
# ## Transformations

# %%
# Transform "TotalCharges" column to numeric using "astype" method fails because of the empty values
# df_contracts['TotalCharges'] = df_contracts['TotalCharges'].astype(float)

# Transform "TotalCharges" column to numeric using "to_numeric" method with "errors" parameter set to "coerce" to replace invalid parsing with NaN
df_contracts['TotalCharges'] = pd.to_numeric(df_contracts['TotalCharges'], errors='coerce')

# Show contracts dataset info
df_contracts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   Tenure            7043 non-null   int64
#  2   Contract          7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 440.3+ KB

# %% [markdown]
# After the transformations, the dataset has 11 missing values in the `TotalCharges` column.

# %% [markdown]
# ## Rename columns

# %%
# Rename "SeniorCitizen" column to "Above65yo" using "rename" method. The "inplace" parameter is set
# to "True" to modify the DataFrame in place
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'}, inplace=True)
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7043 non-null   object
#  1   gender      7043 non-null   object
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   object
#  4   Dependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %%
# Rename all columns in the customers dataset using "columns" attribute
df_customers.columns = ['CustomerID', 'Gender', 'Above65yo', 'HasPartner', 'HasDependents']
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CustomerID     7043 non-null   object
#  1   Gender         7043 non-null   object
#  2   Above65yo      7043 non-null   int64
#  3   HasPartner     7043 non-null   object
#  4   HasDependents  7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB

# %% [markdown]
# ## Merge datasets

# %%
# Rename columns to "CustomerID" in the services and contracts datasets
df_services.rename(columns={"customerID": "CustomerID"}, inplace=True)
df_contracts.rename(columns={"customerID": "CustomerID"}, inplace=True)

# %%
# Merge the customers, services, and contracts datasets using "merge" method
# df_churn = pd.merge(df_customers, df_services, on='CustomerID')
# df_churn = pd.merge(df_churn, df_contracts, on='CustomerID')
df_churn = df_customers.merge(df_services, on='CustomerID').merge(df_contracts, on='CustomerID')

# Show the merged dataset
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CustomerID        7043 non-null   object
#  1   Gender            7043 non-null   object
#  2   Above65yo         7043 non-null   int64
#  3   HasPartner        7043 non-null   object
#  4   HasDependents     7043 non-null   object
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Tenure            7043 non-null   int64
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Handle missing values

# %%
# Detect missing values per column in the merged dataset
df_churn.isnull().sum()
# Out:
# CustomerID           0
# Gender               0
# Above65yo            0
# HasPartner           0
# HasDependents        0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
# Detect missing values in the "TotalCharges" column
df_churn["TotalCharges"].isnull().sum()
# Out:
# 11

# %%
# Show lines with missing values
df_churn[df_churn.isnull().any(axis=1)]
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 488   4472-LVYGI  Female          0        Yes           Yes           No
# 753   3115-CZMZD    Male          0         No           Yes          Yes
# 936   5709-LVOEQ  Female          0        Yes           Yes          Yes
# 1082  4367-NUYAO    Male          0        Yes           Yes          Yes
# 1340  1371-DWPAZ  Female          0        Yes           Yes           No
# 3331  7644-OMVMY    Male          0        Yes           Yes          Yes
# 3826  3213-VVOLG    Male          0        Yes           Yes          Yes
# 4380  2520-SGTTA  Female          0        Yes           Yes          Yes
# 5218  2923-ARZLG    Male          0        Yes           Yes          Yes
# 6670  4075-WKNIU  Female          0        Yes           Yes          Yes
# 6754  2775-SEFEE    Male          0         No           Yes          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# ...

# %% [markdown]
# ## Remove missing values

# %%
# Drop columns with missing values
# df_churn.drop(columns=['TotalCharges'], inplace=False, axis=1)
df_churn.dropna(axis=1, inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# ...

# %%
# Drop lines with missing values in the "TotalCharges" column
df_churn.dropna(subset=['TotalCharges'], inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
# Remove column if ALL values are missing
df_churn.dropna(axis=1, how='all', inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
# Remove lines if ANY value is missing
df_churn.dropna(axis=0, inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ## Populate missing values

# %%
# Fill missing values in ALL columns with 0
df_churn.fillna(0, inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
# Fill missing values in the "TotalCharges" column with 0
df_churn.fillna(value={'TotalCharges': 0}, inplace=False)
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ## Univariate analysis
#
# - A faixa etária do cliente tem uma forte correlação com a taxa de cancelamento.
# - Um cliente com menos de seis meses de contrato é mais propenso a cancelar o serviço.
# - Clientes com contrato mensal são mais propensos a cancelar o serviço.

# %%
# Identify unique values in the "Churn" column
df_churn.Churn.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
# Count clients by "Churn" value
df_churn.Churn.value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
# Count clients by "Churn" value in percentage
df_churn.Churn.value_counts(normalize=True)
# Out:
# Churn
# No    0.734630129206304
# Yes   0.265369870793696
# Name: proportion, dtype: float64

# %%
# Plot "Churn" column
ax = df_churn.Churn.value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5174'), Text(0, 0, '1869')]

# %%
# What are the types of contracts?
df_churn.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
# Plot "Contract" column
ax = df_churn.Contract.value_counts().plot(kind='bar')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '3875'), Text(0, 0, '1695'), Text(0, 0, '1473')]

# %%
# How long do clients stay with the company?
df_churn.Tenure.plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# How much do clients pay monthly?t
df_churn.MonthlyCharges.plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Show statistics for the "Tenure" column
df_churn.Tenure.describe()
# Out:
# count   7043.000000000000000
# mean      32.371148658242227
# std       24.559481023094460
# min        0.000000000000000
# 25%        9.000000000000000
# 50%       29.000000000000000
# 75%       55.000000000000000
# max       72.000000000000000
# Name: Tenure, dtype: float64

# %%
# What is the mode of the "Tenure" column?
df_churn.Tenure.mode()
# Out:
# 0    1
# Name: Tenure, dtype: int64

# %%
# Standard deviation of the "Tenure" column
df_churn.Tenure.std()
# Out:
# 24.55948102309446

# %%
# Coefficient of variation of the "Tenure" column
df_churn.Tenure.std() / df_churn.Tenure.mean() * 100
# Out:
# 75.86842617906674

# %%
# How many clients have been with the company for 1 month?
count = len(df_churn[df_churn.Tenure == 1])
percentage = count / len(df_churn) * 100

print(f'{count} clients ({percentage:.2f}%) have been with the company for 1 month')
# Out:
# 613 clients (8.70%) have been with the company for 1 month

# %%
# How many clients have been with the company for 1 to 6 months?
count = len(df_churn[(df_churn.Tenure >= 1) & (df_churn.Tenure <= 6)])
percentage = count / len(df_churn) * 100

print(f'{count} clients ({percentage:.2f}%) have been with the company for 1 to 6 months')
# Out:
# 1470 clients (20.87%) have been with the company for 1 to 6 months

# %%
# Group clients by "Tenure" and count the number of clients in each group
df_churn.groupby('Tenure').Tenure.count().sort_values(ascending=False)
# Out:
# Tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: Tenure, Length: 73, dtype: int64

# %%
df_churn.groupby('Tenure').Tenure.count().sort_values().plot.barh(figsize=(10, 20))
# Out:
# <Axes: ylabel='Tenure'>

# %% [markdown]
# ## Bivariate analysis

# %% [markdown]
# ### Hipótese 1 - Clientes com contrato mensal têm maior probabilidade de cancelamento

# %%
# Cross-tabulate "Churn" and "Contract" columns (tabela de contingência)
pd.crosstab(df_churn.Churn, df_churn.Contract, margins=True, margins_name='Total')
# Out:
# Contract  Month-to-month  One year  Two year  Total
# Churn
# No                  2220      1307      1647   5174
# Yes                 1655       166        48   1869
# Total               3875      1473      1695   7043

# %%
pd.crosstab(df_churn.Churn, df_churn.Contract, normalize="index", margins=True, margins_name='Total')
# Out:
# Contract    Month-to-month          One year          Two year
# Churn
# No       0.429068419018168 0.252609199845381 0.318322381136452
# Yes      0.885500267522739 0.088817549491707 0.025682182985554
# Total    0.550191679681954 0.209143830753940 0.240664489564106

# %% [markdown]
# Considerando o público total, os clientes com contrato mensal representam 55%. Porém, se considerarmos apenas os clientes que abandonaram o serviço, 88% deles tinham contrato mensal.

# %% [markdown]
# #### Correlação de variáveis qualitativas
#
# Para avaliar a correlação entre duas variáveis categóricas (qualitativas), devemos executar um teste de hipótese chamado Chi-Square ou Qui-Quadrado de Pearson. Em um teste de hipóteses, duas hipóteses são formuladas:
#
# - H0 (hipótese nula): as duas variáveis são independentes
# - H1 (hipótese complementar): as duas variáveis são complementares
#
# O teste serve para confirmar ou recusar a hipótese nula (H0). Quando a probabilidade de observarmos H0 é inferior a 0.05 (p=value), recusamos a hipótese nula e seguimos com a complementar.

# %%
df_crosstab_churn_contract = pd.crosstab(df_churn.Churn, df_churn.Contract)

# %%
# Calculate scores and p-values
from scipy.stats import chi2_contingency

chi_scores_churn_contract = chi2_contingency(df_crosstab_churn_contract)
chi_scores_churn_contract
# Out:
# Chi2ContingencyResult(statistic=1184.5965720837926, pvalue=5.863038300673393e-258, dof=2, expected_freq=array([[2846.69175067, 1082.11018032, 1245.198069  ],
#        [1028.30824933,  390.88981968,  449.801931  ]]))

# %%
scores_churn_contract = pd.Series(chi_scores_churn_contract[0])
p_values_churn_contract = pd.Series(chi_scores_churn_contract[1])

# %%
pd.set_option('display.float_format', '{:.15f}'.format)

# %%
df_chi_scores_churn_contract = pd.DataFrame({'chi2': scores_churn_contract, 'p-value': p_values_churn_contract})
df_chi_scores_churn_contract
# Out:
#                   chi2           p-value
# 0 1184.596572083792580 0.000000000000000

# %% [markdown]
# Conforme o teste estatístico (Qui-Square), o p-value é menor ou igual a 0.05. Pelo qui2 alto, podemos afirmar que há uma forte correlação. Portanto, seguimos com a hipótese complementar.

# %% [markdown]
# ### Hipótese 2 - Clientes com menos de seis meses de contrato têm maior probabilidade de cancelamento

# %%
import numpy as np

# Create a new column "ContractLessThan6Months" with 1 for clients with less than 6 months of contract and 0 otherwise
df_churn["ContractLessThan6Months"] = np.where(df_churn.Tenure < 6, 1, 0)
df_churn
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 1     5575-GNVDE    Male          0         No            No          Yes
# 2     3668-QPYBK    Male          0         No            No          Yes
# 3     7795-CFOCW    Male          0         No            No           No
# 4     9237-HQITU  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7038  6840-RESVB    Male          0        Yes           Yes          Yes
# 7039  2234-XADUH  Female          0        Yes           Yes          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
# 7042  3186-AJIEK    Male          0         No            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
df_crosstab_churn_tenure = pd.crosstab(df_churn.Churn, df_churn.ContractLessThan6Months)
df_crosstab_churn_tenure
# Out:
# ContractLessThan6Months     0    1
# Churn
# No                       4547  627
# Yes                      1125  744

# %%
chi_scores_churn_tenure = chi2_contingency(df_crosstab_churn_tenure)
chi_scores_churn_tenure
# Out:
# Chi2ContingencyResult(statistic=669.7216158287102, pvalue=1.1485390172689518e-147, dof=1, expected_freq=array([[4166.82209286, 1007.17790714],
#        [1505.17790714,  363.82209286]]))

# %%
scores_churn_tenure = pd.Series(chi_scores_churn_tenure[0])
p_values_churn_tenure = pd.Series(chi_scores_churn_tenure[1])

# %%
df_chi_scores_churn_tenure = pd.DataFrame({'chi2': scores_churn_tenure, 'p-value': p_values_churn_tenure})
df_chi_scores_churn_tenure
# Out:
#                  chi2           p-value
# 0 669.721615828710242 0.000000000000000

# %% [markdown]
# Como o p-value é menor ou igual a 0.05, recusamos a hipótese nula e seguimos com a complementar.

# %%
# Correlation between "Tenure" and "TotalCharges" columns (two numeric columns)
df_churn.Tenure.corr(df_churn.TotalCharges)
# Out:
# 0.8258804609332018

# %%
df_churn.Tenure.corr(df_churn.TotalCharges, method="spearman")
# Out:
# 0.8891770805365491

# %%
# Scatter plot between "Tenure" and "TotalCharges" columns
df_churn.plot.scatter(x='Tenure', y='TotalCharges')
# Out:
# <Axes: xlabel='Tenure', ylabel='TotalCharges'>

# %% [markdown]
# ### Hipótese 3 - A faixa etária do cliente tem uma forte correlação com a taxa de cancelamento

# %%
# Cross-tabulate "Churn" and "Above65yo" columns
df_crosstab_churn_above65yo = pd.crosstab(df_churn.Churn, df_churn.Above65yo)
df_crosstab_churn_above65yo
# Out:
# Above65yo     0    1
# Churn
# No         4508  666
# Yes        1393  476

# %%
chi_scores_churn_above65yo = chi2_contingency(df_crosstab_churn_above65yo)
chi_scores_churn_above65yo
# Out:
# Chi2ContingencyResult(statistic=159.42630036838742, pvalue=1.5100668050923772e-36, dof=1, expected_freq=array([[4335.05239245,  838.94760755],
#        [1565.94760755,  303.05239245]]))

# %%
scores_churn_above65yo = pd.Series(chi_scores_churn_above65yo[0])
p_values_churn_above65yo = pd.Series(chi_scores_churn_above65yo[1])

df_chi_scores_churn_above65yo = pd.DataFrame({'chi2': scores_churn_above65yo, 'p-value': p_values_churn_above65yo})
df_chi_scores_churn_above65yo
# Out:
#                  chi2           p-value
# 0 159.426300368387416 0.000000000000000

# %% [markdown]
# Como o p-value é menor ou igual a 0.05, recusamos a hipótese nula e seguimos com a complementar.

# %% [markdown]
# ### Hipótese 4 - Contrato mensal é mais propenso a cancelamento

# %%
# Create a new column "IsMonthlyContract" with 1 for clients with monthly contract and 0 otherwise
df_churn["IsMonthlyContract"] = np.where(df_churn.Contract == 'Month-to-month', 1, 0)
df_churn.IsMonthlyContract
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    1
# 7041    1
# 7042    0
# Name: IsMonthlyContract, Length: 7043, dtype: int64

# %%
df_crosstab_churn_is_monthly_contract = pd.crosstab(df_churn.Churn, df_churn.IsMonthlyContract)
df_crosstab_churn_is_monthly_contract
# Out:
# IsMonthlyContract     0     1
# Churn
# No                 2954  2220
# Yes                 214  1655

# %%
chi_scores_churn_is_monthly_contract = chi2_contingency(df_crosstab_churn_is_monthly_contract)
chi_scores_churn_is_monthly_contract
# Out:
# Chi2ContingencyResult(statistic=1153.971661109348, pvalue=6.147585925548496e-253, dof=1, expected_freq=array([[2327.30824933, 2846.69175067],
#        [ 840.69175067, 1028.30824933]]))

# %%
scores_churn_is_monthly_contract = pd.Series(chi_scores_churn_is_monthly_contract[0])
p_values_churn_is_monthly_contract = pd.Series(chi_scores_churn_is_monthly_contract[1])

df_chi_scores_churn_is_monthly_contract = pd.DataFrame({'chi2': scores_churn_is_monthly_contract, 'p-value': p_values_churn_is_monthly_contract})
df_chi_scores_churn_is_monthly_contract
# Out:
#                   chi2           p-value
# 0 1153.971661109347906 0.000000000000000

# %% [markdown]
# ## Detecting outliers

# %%
# Remove null values
df_churn.dropna(axis=0, inplace=True)
df_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7032 entries, 0 to 7042
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CustomerID               7032 non-null   object
#  1   Gender                   7032 non-null   object
#  2   Above65yo                7032 non-null   int64
#  3   HasPartner               7032 non-null   object
#  4   HasDependents            7032 non-null   object
#  5   PhoneService             7032 non-null   object
#  6   MultipleLines            7032 non-null   object
#  7   InternetService          7032 non-null   object
#  8   OnlineSecurity           7032 non-null   object
#  9   OnlineBackup             7032 non-null   object
#  10  DeviceProtection         7032 non-null   object
#  11  TechSupport              7032 non-null   object
#  12  StreamingTV              7032 non-null   object
#  13  StreamingMovies          7032 non-null   object
# ...

# %%
# Box plot geral
df_churn.TotalCharges.plot.box()
# Out:
# <Axes: >

# %%
# Box plot agrupado por "Contract"
df_churn.boxplot(column='TotalCharges', by='Contract')
# Out:
# <Axes: title={'center': 'TotalCharges'}, xlabel='Contract'>

# %%
# Create DataFrame with only month-to-month contracts
df_churn_monthly = df_churn[df_churn.Contract == 'Month-to-month']
df_churn_monthly
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 0     7590-VHVEG  Female          0        Yes            No           No
# 2     3668-QPYBK    Male          0         No            No          Yes
# 4     9237-HQITU  Female          0         No            No          Yes
# 5     9305-CDSKC  Female          0         No            No          Yes
# 6     1452-KIOVK    Male          0         No           Yes          Yes
# ...          ...     ...        ...        ...           ...          ...
# 7033  9767-FFLEM    Male          0         No            No          Yes
# 7034  0639-TSIQW  Female          0         No            No          Yes
# 7035  8456-QDAVC    Male          0         No            No          Yes
# 7040  4801-JZAZL  Female          0        Yes           Yes           No
# 7041  8361-LTMKD    Male          1        Yes            No          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %%
# Histogram of "TotalCharges" for month-to-month contracts to check if it follows a normal distribution
df_churn_monthly.TotalCharges.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Tukey Method
#
# The Tukey method is based on the interquartile range (IQR), which is the difference between the third quartile (Q3) and the first quartile (Q1). The IQR is used to define the lower and upper limits of the data distribution. Any value outside these limits is considered an outlier. It's used for **non-normal distributions.**

# %%
# Método de Tukey para detecção de outliers. O método de Tukey é baseado no intervalo interquartil (IQR), aplicado em distribuições não-normais.
# IQR = Q3 - Q1
Q1_TotalCharges = df_churn_monthly.TotalCharges.quantile(0.25)
Q3_TotalCharges = df_churn_monthly.TotalCharges.quantile(0.75)
IQR_TotalCharges = Q3_TotalCharges - Q1_TotalCharges
IQR_TotalCharges
# Out:
# 1906.4

# %%
# Limite inferior = Q1 - 1.5 * IQR
inferior_limit_TotalCharges = Q1_TotalCharges - 1.5 * IQR_TotalCharges

# Limite superior = Q3 + 1.5 * IQR
superior_limit_TotalCharges = Q3_TotalCharges + 1.5 * IQR_TotalCharges

inferior_limit_TotalCharges, superior_limit_TotalCharges
# Out:
# (-2699.5000000000005, 4926.1)

# %%
df_churn_monthly[(df_churn_monthly.TotalCharges < inferior_limit_TotalCharges) | (df_churn_monthly.TotalCharges > superior_limit_TotalCharges)]
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 13    0280-XJGEX    Male          0         No            No          Yes
# 61    1215-FIGMP    Male          0         No            No          Yes
# 93    6067-NGCEU  Female          0         No            No          Yes
# 110   0486-HECZI    Male          0        Yes            No          Yes
# 197   6168-YBYNP    Male          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 6897  2363-BJLSL    Male          0         No            No          Yes
# 6952  6394-MFYNG  Female          0         No            No          Yes
# 6965  7789-CRUVC  Female          1        Yes            No          Yes
# 7023  1035-IPQPU  Female          1        Yes            No          Yes
# 7034  0639-TSIQW  Female          0         No            No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ### Z-Score
#
# The Z-Score is a statistical measurement that describes a value's relationship to the mean of a group of values. It is measured in terms of standard deviations from the mean. If the Z-Score is greater than 3 or less than -3, the data point is considered an outlier. It's used for **normally distributed data.**

# %%
from scipy.stats import zscore

# %%
z_scores_TotalCharges = np.abs(zscore(df_churn_monthly.TotalCharges))
z_scores_TotalCharges
# Out:
# 0      0.830035854105835
# 2      0.781512944511796
# 4      0.754555772515107
# 5      0.340066014124648
# 6      0.359519077072167
#               ...
# 7033   0.778346771186232
# 7034   3.418910216654943
# 7035   0.077987048610201
# 7040   0.633837218378213
# 7041   0.658532466747594
# Name: TotalCharges, Length: 3875, dtype: float64

# %%
df_churn_monthly[z_scores_TotalCharges > 3.0]
# Out:
#       CustomerID  Gender  Above65yo HasPartner HasDependents PhoneService  \
# 93    6067-NGCEU  Female          0         No            No          Yes
# 197   6168-YBYNP    Male          0         No            No          Yes
# 339   1343-EHPYB    Male          0        Yes            No          Yes
# 402   0979-PHULV    Male          0        Yes           Yes          Yes
# 445   7752-XUSCI  Female          0         No            No          Yes
# ...          ...     ...        ...        ...           ...          ...
# 6565  1548-FEHVL    Male          0        Yes            No          Yes
# 6587  7426-GSWPO    Male          1         No            No          Yes
# 6713  4989-LIXVT    Male          1         No            No          Yes
# 7023  1035-IPQPU  Female          1        Yes            No          Yes
# 7034  0639-TSIQW  Female          0         No            No          Yes
#
#      MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# ...

# %% [markdown]
# ## Automating the process

# %%
import sweetviz as sv

sv_churn_report = sv.analyze(df_churn, target_feat='Churn')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
sv_churn_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
sv_churn_report.show_html(filepath='./sv_churn_report.html', open_browser=True, layout='widescreen')
# Out:
# Report ./sv_churn_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ## Challenge
#
# Usando a base de dados `netflix_daily_top_10.csv`, analise e extraia as seguintes informações:
#
# - Tipos de dados disponíveis
# - Período da análise feita
# - Tamanho da base de dados
# - Verificar dados nulos
# - Outliers

# %%
# Read the dataset
df_netflix = pd.read_csv('./datasets/netflix_daily_top_10.csv')

# %%
# Visualize type of date available (tipos de dados disponíveis)
df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   object
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   object
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 554.8+ KB

# %%
# Parse date fields
df_netflix['Netflix Release Date'] = pd.to_datetime(df_netflix['Netflix Release Date'])
df_netflix['As of'] = pd.to_datetime(df_netflix['As of'])

df_netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7100 entries, 0 to 7099
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   As of                 7100 non-null   datetime64[ns]
#  1   Rank                  7100 non-null   int64
#  2   Year to Date Rank     7100 non-null   object
#  3   Last Week Rank        7100 non-null   object
#  4   Title                 7100 non-null   object
#  5   Type                  7100 non-null   object
#  6   Netflix Exclusive     4599 non-null   object
#  7   Netflix Release Date  7100 non-null   datetime64[ns]
#  8   Days In Top 10        7100 non-null   int64
#  9   Viewership Score      7100 non-null   int64
# dtypes: datetime64[ns](2), int64(3), object(5)
# memory usage: 554.8+ KB

# %%
# Período da análise feita
df_netflix['As of'].min(), df_netflix['As of'].max()
# Out:
# (Timestamp('2020-04-01 00:00:00'), Timestamp('2022-03-11 00:00:00'))

# %%
# Tamanho do dataset
df_netflix.shape
# Out:
# (7100, 10)

# %%
# Verificar dados nulos
df_netflix.isnull().sum()
# Out:
# As of                      0
# Rank                       0
# Year to Date Rank          0
# Last Week Rank             0
# Title                      0
# Type                       0
# Netflix Exclusive       2501
# Netflix Release Date       0
# Days In Top 10             0
# Viewership Score           0
# dtype: int64

# %%
# Detectar outliers
df_netflix.describe()
# Out:
#                                As of                 Rank  \
# count                           7100 7100.000000000000000
# mean   2021-03-21 12:00:00.000000256    5.500000000000000
# min              2020-04-01 00:00:00    1.000000000000000
# 25%              2020-09-25 00:00:00    3.000000000000000
# 50%              2021-03-21 12:00:00    5.500000000000000
# 75%              2021-09-15 00:00:00    8.000000000000000
# max              2022-03-11 00:00:00   10.000000000000000
# std                              NaN    2.872483617971048
#
#                 Netflix Release Date       Days In Top 10     Viewership Score
# count                           7100 7100.000000000000000 7100.000000000000000
# mean   2020-06-21 08:05:32.619718144   24.123661971830987  122.790140845070425
# min              2007-01-15 00:00:00    1.000000000000000    1.000000000000000
# 25%              2020-04-26 00:00:00    3.000000000000000   19.000000000000000
# ...

# %%
# Analyze with Sweetviz
sv_netflix_report = sv.analyze(df_netflix)
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)

# %%
# Visualize the report
sv_netflix_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.7.1 | (c) OpenJS Foundation and other contributors | jquery.org/license */
# ...

# %%
sv_netflix_report.show_html(filepath='./sv_netflix_report.html', open_browser=True, layout='widescreen')
# Out:
# Report ./sv_netflix_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# Baseado no relatório gerado, nós podemos ver que existem outliers nas colunas "Days In Top 10" e "Viewership Score". Como os dados não seguem uma distribuição normal, podemos usar o método de Tukey para identificar os outliers.

# %% [markdown]
# ### Tukey Method

# %% [markdown]
# #### Days In Top 10

# %%
Q1_DaysInTop10 = df_netflix['Days In Top 10'].quantile(0.25)
Q3_DaysInTop10 = df_netflix['Days In Top 10'].quantile(0.75)
IQR_DaysInTop10 = Q3_DaysInTop10 - Q1_DaysInTop10
IQR_DaysInTop10
# Out:
# 15.0

# %%
inferior_limit_DaysInTop10 = Q1_DaysInTop10 - 1.5 * IQR_DaysInTop10
superior_limit_DaysInTop10 = Q3_DaysInTop10 + 1.5 * IQR_DaysInTop10
inferior_limit_DaysInTop10, superior_limit_DaysInTop10
# Out:
# (-19.5, 40.5)

# %%
df_netflix_days_in_top_10_outliers = df_netflix[(df_netflix['Days In Top 10'] < inferior_limit_DaysInTop10) | (df_netflix['Days In Top 10'] > superior_limit_DaysInTop10)]
df_netflix_days_in_top_10_outliers
# Out:
#           As of  Rank Year to Date Rank Last Week Rank          Title  \
# 438  2020-05-14     9                 9              -          Ozark
# 447  2020-05-15     8                 9             10          Ozark
# 458  2020-05-16     9                 8              -          Ozark
# 489  2020-05-19    10                 -              7          Ozark
# 629  2020-06-02    10                 -              -    Outer Banks
# ...         ...   ...               ...            ...            ...
# 7053 2022-03-07     4                 3              4  Love is Blind
# 7063 2022-03-08     4                 4              4  Love is Blind
# 7074 2022-03-09     5                 4              5  Love is Blind
# 7085 2022-03-10     6                 5              5  Love is Blind
# 7094 2022-03-11     5                 6              6  Love is Blind
#
#          Type Netflix Exclusive Netflix Release Date  Days In Top 10  \
# ...

# %% [markdown]
# #### Viewership Score

# %%
Q1_Viewership = df_netflix['Viewership Score'].quantile(0.25)
Q3_Viewership = df_netflix['Viewership Score'].quantile(0.75)
IQR_Viewership = Q3_Viewership - Q1_Viewership
IQR_Viewership
# Out:
# 109.0

# %%
inferior_limit_Viewership = Q1_Viewership - 1.5 * IQR_Viewership
superior_limit_Viewership = Q3_Viewership + 1.5 * IQR_Viewership
inferior_limit_Viewership, superior_limit_Viewership
# Out:
# (-144.5, 291.5)

# %%
df_netflix_viewership_outliers = df_netflix[(df_netflix['Viewership Score'] < inferior_limit_Viewership) | (df_netflix['Viewership Score'] > superior_limit_Viewership)]
df_netflix_viewership_outliers
# Out:
#           As of  Rank Year to Date Rank Last Week Rank  \
# 236  2020-04-24     7                 7              2
# 247  2020-04-25     8                 7              2
# 255  2020-04-26     6                 8              3
# 269  2020-04-27    10                 6              4
# 2382 2020-11-25     3                 2              3
# ...         ...   ...               ...            ...
# 7008 2022-03-02     9                 6              3
# 7063 2022-03-08     4                 4              4
# 7074 2022-03-09     5                 4              5
# 7085 2022-03-10     6                 5              5
# 7094 2022-03-11     5                 6              6
#
#                              Title     Type Netflix Exclusive  \
# 236   Tiger King: Murder, Mayhem …  TV Show               Yes
# 247   Tiger King: Murder, Mayhem …  TV Show               Yes
# 255   Tiger King: Murder, Mayhem …  TV Show               Yes
# ...
